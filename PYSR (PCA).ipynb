# %%
from pysr import PySRRegressor
import numpy as np

# %%
df = np.load('./nac_filtered.npz')
X = df['arr_0']
X_hat = df['arr_1']
y = df['arr_2']

# %%
X.shape
# Out:
# (100, 5)

# %%
X_hat.shape
# Out:
# (100, 3)

# %% [markdown]
# ## Symbolic Regression for Original Data

# %%
model_1 = PySRRegressor(
    niterations=5,
    binary_operators=["+", "*", "-"],
    unary_operators=["sqrt"],
    model_selection="best",
    loss="loss(x,y) = (x-y)^2",
)

# %%
model_1.fit(X, y) # Original
# Out:
# /home/quokka/.local/lib/python3.9/site-packages/pysr/sr.py:325: UserWarning:
# Your Python version is statically linked to libpython. For example, this could be the python included with conda, or maybe your system's built-in python.
# This will still work, but the precompilation cache for Julia will be turned off, which may result in slower startup times on the initial pysr() call.
#
# To install a Python version that is dynamically linked to libpython, pyenv is recommended (https://github.com/pyenv/pyenv). With pyenv, you can run: `PYTHON_CONFIGURE_OPTS="--enable-shared" pyenv install 3.9.10` to install Python 3.9.10 with dynamic linking.
#
# To silence this warning, you can run pysr.silence_julia_warning() after importing pysr.
#   warnings.warn(
#   Activating project at `~/.julia/environments/pysr-0.7.10`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/pysr-0.7.10/Project.toml`
#   No Changes to `~/.julia/environments/pysr-0.7.10/Manifest.toml`
#   No Changes to `~/.julia/environments/pysr-0.7.10/Project.toml`
#   No Changes to `~/.julia/environments/pysr-0.7.10/Manifest.toml`
# Started!
#
# Cycles per second: 1.100e+04
# Head worker occupation: 12.6%
# Progress: 58 / 500 total iterations (11.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  (x0 + (x2 - 0.9988725))
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x0 - sqrt_abs(x3)) + (x2 - 0.32644212))
# 9           1.173e-02  9.614e-02  ((x0 - x3) + ((x2 * x2) + -0.32950872))
# 11          1.173e-02  5.439e-06  ((x0 - x3) + ((x2 * (x2 * 1.0012028)) + -0.32988018))
# 14          5.512e-03  2.517e-01  (x3 - (((sqrt_abs(x3) + 0.16049644) - x2) + (x3 - (x0 * x0))))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.160e+04
# Head worker occupation: 6.9%
# Progress: 124 / 500 total iterations (24.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  (x0 + (x2 - 0.9988725))
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.173e-02  9.614e-02  ((x0 - x3) + ((x2 * x2) + -0.32950872))
# 10          1.118e-02  4.756e-02  ((x2 - sqrt_abs(x3)) - ((0.23208632 - x0) * x0))
# 11          7.112e-03  4.528e-01  ((((x2 * x2) + x0) + (x3 * -0.77270883)) - 0.44517365)
# 12          5.405e-03  2.745e-01  (((x2 + ((x0 * x0) - sqrt_abs(x3))) * 0.9774193) + -0.15672679)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.170e+04
# Head worker occupation: 5.4%
# Progress: 186 / 500 total iterations (37.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  (x0 + (x2 - 0.9988725))
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.173e-02  9.614e-02  ((x0 - x3) + ((x2 * x2) + -0.32950872))
# 10          5.512e-03  7.552e-01  ((((x0 * x0) + x2) - sqrt_abs(x3)) - 0.16048111)
# 12          5.405e-03  9.819e-03  (((x2 + ((x0 * x0) - sqrt_abs(x3))) * 0.9774193) + -0.15672679)
# 16          5.264e-03  6.592e-03  (((x2 - sqrt_abs(x3)) - (((sqrt_abs(sqrt_abs(x2)) * 0.06571236) - x0) * x0)) + -0.13350727)
# 19          4.952e-03  2.036e-02  (((x2 - sqrt_abs(x3)) - ((((0.30229726 - (x0 * 0.24447843)) * sqrt_abs(x2)) - x0) * x0)) + -0.11550446)
# 20          4.864e-03  1.793e-02  (((x2 - sqrt_abs(x3)) - ((((0.35284346 - (x0 * 0.29524472)) * sqrt_abs(sqrt_abs(x2))) - x0) * x0)) + -0.098741464)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.190e+04
# Head worker occupation: 4.7%
# Progress: 249 / 500 total iterations (49.800%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  (x0 + (x2 - 0.9988725))
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.173e-02  9.614e-02  ((x0 - x3) + ((x2 * x2) + -0.32950872))
# 10          5.512e-03  7.552e-01  ((((x0 * x0) + x2) - sqrt_abs(x3)) - 0.16048111)
# 12          5.405e-03  9.819e-03  (((x2 + ((x0 * x0) - sqrt_abs(x3))) * 0.9774193) + -0.15672679)
# 14          0.000e+00  1.151e+01  ((((x0 * x0) + (x2 * (x2 * 0.9999999))) - 3.1052036e-6) - sqrt_abs(x3))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.190e+04
# Head worker occupation: 4.8%
# Progress: 316 / 500 total iterations (63.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  ((x0 - 0.9988847) + x2)
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.054e-02  2.034e-01  (x2 + ((x0 * x0) - sqrt_abs(sqrt_abs(x3))))
# 10          0.000e+00  2.303e+01  ((x0 * x0) - (sqrt_abs(x3) - (x2 * x2)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.200e+04
# Head worker occupation: 4.3%
# Progress: 380 / 500 total iterations (76.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  ((x0 - 0.9988847) + x2)
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.054e-02  2.034e-01  (x2 + ((x0 * x0) - sqrt_abs(sqrt_abs(x3))))
# 10          0.000e+00  2.303e+01  ((x0 * x0) - (sqrt_abs(x3) - (x2 * x2)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.230e+04
# Head worker occupation: 4.1%
# Progress: 453 / 500 total iterations (90.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006237807
# 3           1.015e-01  3.544e-01  (x0 - x3)
# 5           6.151e-02  2.505e-01  ((x0 - 0.9988847) + x2)
# 7           2.115e-02  5.337e-01  ((x0 - x3) + (x2 - 0.48999974))
# 8           1.291e-02  4.936e-01  ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 9           1.054e-02  2.034e-01  (x2 + ((x0 * x0) - sqrt_abs(sqrt_abs(x3))))
# 10          0.000e+00  2.303e+01  ((x0 * x0) - (sqrt_abs(x3) - (x2 * x2)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations = [
# 	   pick     score                                     equation      loss  \
# 	0        0.000000                                  0.006237807  0.206222
# 	1        0.354428                                    (x0 - x3)  0.101504
# 	2        0.250470                      ((x0 - 0.9988847) + x2)  0.061507
# 	3        0.533676              ((x0 - x3) + (x2 - 0.48999974))  0.021154
# 	4        0.493606   ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)  0.012913
# 	5        0.203438  (x2 + ((x0 * x0) - sqrt_abs(sqrt_abs(x3))))  0.010536
# 	6  >>>>       inf     ((x0 * x0) - (sqrt_abs(x3) - (x2 * x2)))  0.000000
#
# 	   complexity
# 	0           1
# 	1           3
# 	2           5
# 	3           7
# 	4           8
# 	5           9
# 	6          10
# ]

# %%
model_1.equations
# Out:
#    complexity      loss     score  \
# 0           1  0.206222  0.000000
# 1           3  0.101504  0.354428
# 2           5  0.061507  0.250470
# 3           7  0.021154  0.533676
# 4           8  0.012913  0.493606
# 5           9  0.010536  0.203438
# 6          10  0.000000       inf
#
#                                       equation  \
# 0                                  0.006237807
# 1                                    (x0 - x3)
# 2                      ((x0 - 0.9988847) + x2)
# 3              ((x0 - x3) + (x2 - 0.48999974))
# 4   ((x2 - (sqrt_abs(x3) - -0.32643783)) + x0)
# 5  (x2 + ((x0 * x0) - sqrt_abs(sqrt_abs(x3))))
# 6     ((x0 * x0) - (sqrt_abs(x3) - (x2 * x2)))
#
#                            sympy_format  \
# 0                   0.00623780700000000
# 1                               x0 - x3
# 2                   x0 + x2 - 0.9988847
# 3             x0 + x2 - x3 - 0.48999974
# 4  x0 + x2 - sqrt(Abs(x3)) - 0.32643783
# 5           x0**2 + x2 - Abs(x3)**(1/4)
# 6         x0**2 + x2**2 - sqrt(Abs(x3))
#
#                                        lambda_format
# 0               PySRFunction(X=>0.00623780700000000)
# 1                           PySRFunction(X=>x0 - x3)
# 2               PySRFunction(X=>x0 + x2 - 0.9988847)
# 3         PySRFunction(X=>x0 + x2 - x3 - 0.48999974)
# 4  PySRFunction(X=>x0 + x2 - sqrt(Abs(x3)) - 0.32...
# 5       PySRFunction(X=>x0**2 + x2 - Abs(x3)**(1/4))
# 6     PySRFunction(X=>x0**2 + x2**2 - sqrt(Abs(x3)))

# %% [markdown]
# ## Symbolic Regression for NAC filtered Data

# %%
model_2 = PySRRegressor(
    niterations=5,
    binary_operators=["+", "*", "-"],
    unary_operators=["sqrt"],
    model_selection="best",
    loss="loss(x,y) = (x-y)^2",
)

# %%
model_2.fit(X_hat, y)
# Out:
# Started!
#
# Cycles per second: 5.020e+02
# Head worker occupation: 6.9%
# Progress: 3 / 500 total iterations (0.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           1.000e-01  7.482e-03  ((x0 - x2) * 0.89356035)
# 7           2.115e-02  7.767e-01  ((x0 + (x1 + -0.490001)) - x2)
# 9           1.898e-02  5.429e-02  ((((x0 - x2) * 0.8716864) + -0.48615685) + x1)
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 6.050e+03
# Head worker occupation: 4.5%
# Progress: 61 / 500 total iterations (12.200%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  ((x0 + (x1 + -0.490001)) - x2)
# 8           1.525e-02  3.272e-01  ((x0 + (x1 + -0.27808696)) - sqrt_abs(x2))
# 9           1.054e-02  3.698e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 7.810e+03
# Head worker occupation: 3.6%
# Progress: 120 / 500 total iterations (24.000%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  (((x1 + x0) - 0.4900004) - x2)
# 8           1.291e-02  4.936e-01  (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 9           1.054e-02  2.034e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 9.440e+03
# Head worker occupation: 3.4%
# Progress: 193 / 500 total iterations (38.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  (((x1 + x0) - 0.4900004) - x2)
# 8           1.291e-02  4.936e-01  (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 9           1.054e-02  2.034e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 9.920e+03
# Head worker occupation: 3.1%
# Progress: 253 / 500 total iterations (50.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  (((x1 + x0) - 0.4900004) - x2)
# 8           1.291e-02  4.936e-01  (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 9           1.054e-02  2.034e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.090e+04
# Head worker occupation: 3.0%
# Progress: 333 / 500 total iterations (66.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  (((x1 + x0) - 0.4900004) - x2)
# 8           1.291e-02  4.936e-01  (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 9           1.054e-02  2.034e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
#
# Cycles per second: 1.180e+04
# Head worker occupation: 3.3%
# Progress: 423 / 500 total iterations (84.600%)
# ==============================
# Hall of Fame:
# -----------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.062e-01  1.025e-07  0.006259763
# 3           1.015e-01  3.544e-01  (x0 - x2)
# 5           6.151e-02  2.505e-01  ((x1 - 0.9988847) + x0)
# 7           2.115e-02  5.337e-01  (((x1 + x0) - 0.4900004) - x2)
# 8           1.291e-02  4.936e-01  (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 9           1.054e-02  2.034e-01  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 10          0.000e+00  2.303e+01  ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
# ==============================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations = [
# 	   pick     score                                     equation      loss  \
# 	0        0.000000                                  0.006259763  0.206222
# 	1        0.354428                                    (x0 - x2)  0.101504
# 	2        0.250470                      ((x1 - 0.9988847) + x0)  0.061507
# 	3        0.533676               (((x1 + x0) - 0.4900004) - x2)  0.021154
# 	4        0.493606     (((x1 + x0) - 0.3264406) - sqrt_abs(x2))  0.012913
# 	5        0.203438  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))  0.010536
# 	6  >>>>       inf     ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))  0.000000
#
# 	   complexity
# 	0           1
# 	1           3
# 	2           5
# 	3           7
# 	4           8
# 	5           9
# 	6          10
# ]

# %%
model_2.equations
# Out:
#    complexity      loss     score  \
# 0           1  0.206222  0.000000
# 1           3  0.101504  0.354428
# 2           5  0.061507  0.250470
# 3           7  0.021154  0.533676
# 4           8  0.012913  0.493606
# 5           9  0.010536  0.203438
# 6          10  0.000000       inf
#
#                                       equation  \
# 0                                  0.006259763
# 1                                    (x0 - x2)
# 2                      ((x1 - 0.9988847) + x0)
# 3               (((x1 + x0) - 0.4900004) - x2)
# 4     (((x1 + x0) - 0.3264406) - sqrt_abs(x2))
# 5  (x1 - (sqrt_abs(sqrt_abs(x2)) - (x0 * x0)))
# 6     ((x1 * x1) - (sqrt_abs(x2) - (x0 * x0)))
#
#                           sympy_format  \
# 0                  0.00625976300000000
# 1                              x0 - x2
# 2                  x0 + x1 - 0.9988847
# 3             x0 + x1 - x2 - 0.4900004
# 4  x0 + x1 - sqrt(Abs(x2)) - 0.3264406
# 5          x0**2 + x1 - Abs(x2)**(1/4)
# 6        x0**2 + x1**2 - sqrt(Abs(x2))
#
#                                        lambda_format
# 0               PySRFunction(X=>0.00625976300000000)
# 1                           PySRFunction(X=>x0 - x2)
# 2               PySRFunction(X=>x0 + x1 - 0.9988847)
# 3          PySRFunction(X=>x0 + x1 - x2 - 0.4900004)
# 4  PySRFunction(X=>x0 + x1 - sqrt(Abs(x2)) - 0.32...
# 5       PySRFunction(X=>x0**2 + x1 - Abs(x2)**(1/4))
# 6     PySRFunction(X=>x0**2 + x1**2 - sqrt(Abs(x2)))
